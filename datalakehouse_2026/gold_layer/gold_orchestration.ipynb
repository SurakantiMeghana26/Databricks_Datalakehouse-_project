# %%
# Gold Layer Orchestration - All Notebooks

notebooks = [
    "/Workspace/Users/musicroomlibrary@gmail.com/Databricks_Datalakehouse-_project/datalakehouse_2026/gold_layer/gold_dim_customeres",
    "/Workspace/Users/musicroomlibrary@gmail.com/Databricks_Datalakehouse-_project/datalakehouse_2026/gold_layer/gold_dim_products",
    "/Workspace/Users/musicroomlibrary@gmail.com/Databricks_Datalakehouse-_project/datalakehouse_2026/gold_layer/gold_fact_sales"
]

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)

print("✅ Gold Layer Orchestration Complete!")
