# %%
# Silver Layer Orchestration - All Notebooks

notebooks = [
    "/Workspace/Users/musicroomlibrary@gmail.com/Databricks_Datalakehouse-_project/datalakehouse_2026/silver_layer/Silver_customeres",
    "/Workspace/Users/musicroomlibrary@gmail.com/Databricks_Datalakehouse-_project/datalakehouse_2026/silver_layer/silver_erp_cust_az12",
    "/Workspace/Users/musicroomlibrary@gmail.com/Databricks_Datalakehouse-_project/datalakehouse_2026/silver_layer/silver_erp_loc_a101",
    "/Workspace/Users/musicroomlibrary@gmail.com/Databricks_Datalakehouse-_project/datalakehouse_2026/silver_layer/silver_erp_px_cat_g1v2",
    "/Workspace/Users/musicroomlibrary@gmail.com/Databricks_Datalakehouse-_project/datalakehouse_2026/silver_layer/silver_products",
    "/Workspace/Users/musicroomlibrary@gmail.com/Databricks_Datalakehouse-_project/datalakehouse_2026/silver_layer/silver_sales"
]

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)

print("✅ Silver Layer Orchestration Complete!")
